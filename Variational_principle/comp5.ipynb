# %%
import gdown

folder_id = "https://drive.google.com/drive/folders/1XEf6H1G5t9kXo70bc0hWNxkoXRttqy8K?usp=sharing"
gdown.download_folder(id=folder_id, output="test_data", quiet=False)

import os
import shutil

root = "/content/test_data"

# 1. Move all files from subdirectories to root
for dirpath, dirnames, filenames in os.walk(root):
    for filename in filenames:
        src = os.path.join(dirpath, filename)
        dst = os.path.join(root, filename)

        if src != dst:
            # If file already exists, overwrite
            if os.path.exists(dst):
                os.remove(dst)
            shutil.move(src, dst)

# 2. Remove all empty subdirectories (bottom-up)
for dirpath, dirnames, filenames in os.walk(root, topdown=False):
    if dirpath != root and not os.listdir(dirpath):
        os.rmdir(dirpath)

print("Done. Final contents:")
print(os.listdir(root))
os.chdir('/content/test_data')
# Out:
# Retrieving folder contents
# Processing file 1VuFU2r1DOO2neqqSOC54J0ZZx3DS9KmD band_V0_0_a_ 1.dat
# Processing file 1z5AnbSuHhNQCUpMearAqczMjnkPqBDAK band_V0_0_a_ 4.dat
# Processing file 19EeuyQx_EekTRK69DyE3EYM1WafUJc2r band_V0_0_a_ 7.dat
# Processing file 1_tCYLdktEgF4dmEWJTb1WFFMAVl1hUga band_V0_0_a_10.dat
# Processing file 1jjx2SH2OQQ_5TA40FKh5b-SneLPvpjjx band_V0_8_a_ 1.dat
# Processing file 1Qy4kSf9Iv2zEpYeNnuhZMPMJu2f2Ra1k band_V0_8_a_ 4.dat
# Processing file 1yPgxkPni8cvhjQfoHRbv97pSzjs_K6iv band_V0_8_a_ 7.dat
# Processing file 1sI6Hq5e55iCV1zYiHS_m2keaAkhQnmRw band_V0_8_a_10.dat
# Processing file 1gZ0x2RGjqkTGhh4i2_4XfNOvVctpsPht psi_k0_V0_0_a_ 1.dat
# Processing file 1LsMWWj1RP4DEGDB8qjMaOqLHqCeQrznj psi_k0_V0_0_a_ 4.dat
# Processing file 16XP4UzbCAMoAz2T3UbZokk2zfPFV4f7h psi_k0_V0_0_a_ 7.dat
# Processing file 1lSAdRh_y85usQJ3gWObOfKDqBtxfD6V7 psi_k0_V0_0_a_10.dat
# Processing file 1utvNqIz2IwbjJC6kj_z6DB4uiRKX0s4O psi_k0_V0_8_a_ 1.dat
# Processing file 1OrqerQyPmizcmX3PNX0dss3UnzJnt3-2 psi_k0_V0_8_a_ 4.dat
# Processing file 1sQJbvneKgh7q-XrTLoJKYikUiSL-MmTA psi_k0_V0_8_a_ 7.dat
# Processing file 1niZTNhgE7B-wN58-YQKUfOUP-4y_ehFD psi_k0_V0_8_a_10.dat
# Processing file 1ZrMtuOaWqsTUqvSpYicJsZRTs6VZqwvf psi_kpi_V0_0_a_ 1.dat
# Processing file 1O3gcc651FJ7NlNEifEIwNYSpRYW8jhQt psi_kpi_V0_0_a_ 4.dat
# Processing file 1TXNTeMGtk9od1gvgNL3Z8e-pYiu_eSgO psi_kpi_V0_0_a_ 7.dat
# Processing file 1ogQEtcwSIfs7qK-zTWl0CY19Gq-nYWRs psi_kpi_V0_0_a_10.dat
# Processing file 14-VGYaf3W9SHMmO5oNFLl4aebnpEaBrv psi_kpi_V0_8_a_ 1.dat
# Processing file 16K_oAvEtfHcjqYF7GGN0PpJlbsE3WS4f psi_kpi_V0_8_a_ 4.dat
# Processing file 1UeM1b0LHpDSXBoH-vpj7WrX3TqCe2IhF psi_kpi_V0_8_a_ 7.dat
# Processing file 1eS9jZn55slQg8cTvCfK6wKGxVx67-9in psi_kpi_V0_8_a_10.dat
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1VuFU2r1DOO2neqqSOC54J0ZZx3DS9KmD
# To: /content/test_data/band_V0_0_a_ 1.dat
# 100%|██████████| 48.9k/48.9k [00:00<00:00, 22.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1z5AnbSuHhNQCUpMearAqczMjnkPqBDAK
# To: /content/test_data/band_V0_0_a_ 4.dat
# 100%|██████████| 48.9k/48.9k [00:00<00:00, 47.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=19EeuyQx_EekTRK69DyE3EYM1WafUJc2r
# To: /content/test_data/band_V0_0_a_ 7.dat
# 100%|██████████| 48.9k/48.9k [00:00<00:00, 25.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1_tCYLdktEgF4dmEWJTb1WFFMAVl1hUga
# To: /content/test_data/band_V0_0_a_10.dat
# 100%|██████████| 48.9k/48.9k [00:00<00:00, 68.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1jjx2SH2OQQ_5TA40FKh5b-SneLPvpjjx
# To: /content/test_data/band_V0_8_a_ 1.dat
# 100%|██████████| 48.9k/48.9k [00:00<00:00, 24.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Qy4kSf9Iv2zEpYeNnuhZMPMJu2f2Ra1k
# To: /content/test_data/band_V0_8_a_ 4.dat
# 100%|██████████| 48.9k/48.9k [00:00<00:00, 57.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1yPgxkPni8cvhjQfoHRbv97pSzjs_K6iv
# To: /content/test_data/band_V0_8_a_ 7.dat
# 100%|██████████| 48.9k/48.9k [00:00<00:00, 58.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1sI6Hq5e55iCV1zYiHS_m2keaAkhQnmRw
# To: /content/test_data/band_V0_8_a_10.dat
# 100%|██████████| 48.9k/48.9k [00:00<00:00, 46.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1gZ0x2RGjqkTGhh4i2_4XfNOvVctpsPht
# To: /content/test_data/psi_k0_V0_0_a_ 1.dat
# 100%|██████████| 31.1k/31.1k [00:00<00:00, 31.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1LsMWWj1RP4DEGDB8qjMaOqLHqCeQrznj
# To: /content/test_data/psi_k0_V0_0_a_ 4.dat
# 100%|██████████| 124k/124k [00:00<00:00, 43.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=16XP4UzbCAMoAz2T3UbZokk2zfPFV4f7h
# To: /content/test_data/psi_k0_V0_0_a_ 7.dat
# 100%|██████████| 217k/217k [00:00<00:00, 47.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1lSAdRh_y85usQJ3gWObOfKDqBtxfD6V7
# To: /content/test_data/psi_k0_V0_0_a_10.dat
# 100%|██████████| 310k/310k [00:00<00:00, 66.5MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1utvNqIz2IwbjJC6kj_z6DB4uiRKX0s4O
# To: /content/test_data/psi_k0_V0_8_a_ 1.dat
# 100%|██████████| 31.1k/31.1k [00:00<00:00, 50.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1OrqerQyPmizcmX3PNX0dss3UnzJnt3-2
# To: /content/test_data/psi_k0_V0_8_a_ 4.dat
# 100%|██████████| 124k/124k [00:00<00:00, 48.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1sQJbvneKgh7q-XrTLoJKYikUiSL-MmTA
# To: /content/test_data/psi_k0_V0_8_a_ 7.dat
# 100%|██████████| 217k/217k [00:00<00:00, 57.6MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1niZTNhgE7B-wN58-YQKUfOUP-4y_ehFD
# To: /content/test_data/psi_k0_V0_8_a_10.dat
# 100%|██████████| 310k/310k [00:00<00:00, 91.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1ZrMtuOaWqsTUqvSpYicJsZRTs6VZqwvf
# To: /content/test_data/psi_kpi_V0_0_a_ 1.dat
# 100%|██████████| 31.1k/31.1k [00:00<00:00, 23.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1O3gcc651FJ7NlNEifEIwNYSpRYW8jhQt
# To: /content/test_data/psi_kpi_V0_0_a_ 4.dat
# 100%|██████████| 124k/124k [00:00<00:00, 83.4MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1TXNTeMGtk9od1gvgNL3Z8e-pYiu_eSgO
# To: /content/test_data/psi_kpi_V0_0_a_ 7.dat
# 100%|██████████| 217k/217k [00:00<00:00, 61.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1ogQEtcwSIfs7qK-zTWl0CY19Gq-nYWRs
# To: /content/test_data/psi_kpi_V0_0_a_10.dat
# 100%|██████████| 310k/310k [00:00<00:00, 61.1MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=14-VGYaf3W9SHMmO5oNFLl4aebnpEaBrv
# To: /content/test_data/psi_kpi_V0_8_a_ 1.dat
# 100%|██████████| 31.1k/31.1k [00:00<00:00, 41.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=16K_oAvEtfHcjqYF7GGN0PpJlbsE3WS4f
# To: /content/test_data/psi_kpi_V0_8_a_ 4.dat
# 100%|██████████| 124k/124k [00:00<00:00, 78.3MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1UeM1b0LHpDSXBoH-vpj7WrX3TqCe2IhF
# To: /content/test_data/psi_kpi_V0_8_a_ 7.dat
# 100%|██████████| 217k/217k [00:00<00:00, 72.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1eS9jZn55slQg8cTvCfK6wKGxVx67-9in
# To: /content/test_data/psi_kpi_V0_8_a_10.dat
# 100%|██████████| 310k/310k [00:00<00:00, 72.2MB/s]
# Done. Final contents:
# ['psi_kpi_V0_8_a_ 4.dat', 'psi_k0_V0_0_a_10.dat', 'band_V0_0_a_10.dat', 'band_V0_0_a_ 1.dat', 'psi_kpi_V0_0_a_ 1.dat', 'psi_k0_V0_8_a_ 1.dat', 'psi_k0_V0_0_a_ 7.dat', 'band_V0_8_a_ 1.dat', 'psi_kpi_V0_0_a_10.dat', 'band_V0_0_a_ 4.dat', 'psi_k0_V0_8_a_ 7.dat', 'band_V0_0_a_ 7.dat', 'psi_kpi_V0_8_a_10.dat', 'psi_k0_V0_0_a_ 4.dat', 'band_V0_8_a_ 7.dat', 'psi_kpi_V0_8_a_ 1.dat', 'psi_kpi_V0_0_a_ 7.dat', 'psi_k0_V0_8_a_ 4.dat', 'band_V0_8_a_ 4.dat', 'psi_kpi_V0_8_a_ 7.dat', 'psi_kpi_V0_0_a_ 4.dat', 'band_V0_8_a_10.dat', 'psi_k0_V0_8_a_10.dat', 'psi_k0_V0_0_a_ 1.dat']
# Download completed

# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore")

plt.style.use('seaborn-v0_8-whitegrid')

# parameters
V0_list = [0.5, 8.5]
a_list = [1, 4, 7, 10]

fig, axs = plt.subplots(2, 4, figsize=(16,6), dpi=120)
axs = axs.flatten()

plot_id = 0

for V0 in V0_list:
    for a in a_list:

        # load file
        fname = f"band_V0_{int(V0)}_a_{a:2d}.dat"
        data = np.genfromtxt(fname, invalid_raise=False)
        data = data[~np.isnan(data[:,0])]

        k = data[:,0]
        E1 = data[:,1]
        E2 = data[:,2]

        # boundary
        k_boundary = np.pi / a
        idx = np.argmin(np.abs(k - k_boundary))

        gap = E2[idx] - E1[idx]

        ax = axs[plot_id]

        # plot bands
        ax.plot(k, E1, linewidth=2, marker='o',
                markevery=np.arange(5,len(k)-5,40), label='E1')

        ax.plot(k, E2, linewidth=2, marker='s',
                markevery=np.arange(5,len(k)-5,40), label='E2')



        # vertical lines
        ax.axvline(k_boundary, linestyle='--', color='black', alpha=0.3)
        ax.axvline(-k_boundary, linestyle='--', color='black', alpha=0.3)

        # labels
        ax.set_title(f"V0={V0}, a={a}, gap≈{gap:.2f}")
        ax.set_xlabel("k")
        ax.set_ylabel("E")

        ax.set_xticks([-np.pi/a, 0, np.pi/a])
        ax.set_xticklabels([r'$-\pi/a$', r'$0$', r'$\pi/a$'])

        ax.grid(alpha=0.3)

        plot_id += 1

# super title
fig.suptitle("Band Structure & Band Gaps vs Lattice Spacing (nk=401, npw=11)",
             fontsize=16)

plt.tight_layout(rect=[0,0,1,0.95])
plt.show()

# %%
fig, axs = plt.subplots(2, 4, figsize=(16,6), dpi=120)
axs = axs.flatten()

plot_id = 0

for V0 in V0_list:
    for a in a_list:

        fname = f"psi_kpi_V0_{int(V0)}_a_{a:2d}.dat"
        data = np.loadtxt(fname)

        x = data[:,0]
        psi1 = data[:,1]
        psi2 = data[:,2]

        ax = axs[plot_id]

        ax.plot(x, psi1, label='E1', linewidth=2)
        ax.plot(x, psi2, label='E2', linewidth=2)

        ax.set_title(f"V0={V0}, a={a}")
        ax.set_xlabel("x")
        ax.set_ylabel(r"$|\psi(x)|^2$")
        ax.legend()

        ax.grid(alpha=0.3)

        plot_id += 1

fig.suptitle("Charge Density at k = π/a (Standing Waves)", fontsize=16)

plt.tight_layout(rect=[0,0,1,0.95])
plt.show()
